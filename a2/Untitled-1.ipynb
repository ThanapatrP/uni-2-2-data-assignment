# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. โหลดไฟล์ที่ชื่อ olympics_cleaned.csv ขึ้นมาใน DataFrame ที่ชื่อ medals

# %%
odf = pd.read_csv("olympics_cleaned.csv")
