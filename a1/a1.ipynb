# %% [markdown]
# # **ธนภัทร พูลโภคา 6710450911 หมู่ 200**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ```1. โหลดไฟล์ที่ชื่อ olympic_cleaned.csv ขึ้นมาใน DataFrame ที่ชื่อ medals```

# %%
medals = pd.read_csv("./olympics_cleaned.csv")
medals
# Out:
#                               Country Code  SummerGame  SummerGold  \
# 0                         Afghanistan  AFG          13           0
# 1                             Algeria  ALG          12           5
# 2                           Argentina  ARG          23          18
# 3                             Armenia  ARM           5           1
# 4                         Australasia  ANZ           2           3
# ..                                ...  ...         ...         ...
# 141                        Yugoslavia  YUG          16          26
# 142  Independent Olympic Participants  IOP           1           0
# 143                            Zambia  ZAM          12           0
# 144                          Zimbabwe  ZIM          12           3
# 145                        Mixed team  ZZX           3           8
#
#      SummerSilver  SummerBronze  WinterGame  WinterGold  WinterSilver  \
# 0               0             2           0           0             0
# ...

# %% [markdown]
# ```2. แสดงจำนวนแถวและจำนวนคอลัมน์ของ medals```

# %%
medals.shape
# Out:
# (146, 10)

# %% [markdown]
# ```3. ตรวจสอบว่ารหัสประเทศ (Code) ไม่มีซ้ำกันด้วย attribute is_unique```

# %%
medals.Code.is_unique
# Out:
# True

# %% [markdown]
# ```4. ตั้งรหัสประเทศให้เป็น index```

# %%
medals.set_index("Code", inplace=True)
medals
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# YUG                         Yugoslavia          16          26            29
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
# ...

# %% [markdown]
# ```5. แสดงคอลัมน์เหรียญทองโอลิมปิคฤดูร้อน```

# %%
medals["SummerGold"]
# Out:
# Code
# AFG     0
# ALG     5
# ARG    18
# ARM     1
# ANZ     3
#        ..
# YUG    26
# IOP     0
# ZAM     0
# ZIM     3
# ZZX     8
# Name: SummerGold, Length: 146, dtype: int64

# %% [markdown]
# ```6. แสดงข้อมูลของประเทศสหรัฐอเมริกา```

# %%
medals[medals.index == "USA"]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# USA           22          96           102            84

# %% [markdown]
# ```7. แสดงเฉพาะข้อมูลของโอลิมปิคฤดูร้อนของทุกประเทศ (คอลัมน์ที่ขึ้นต้นด้วยคำว่า Summer)```

# %%
medals.loc[ :, medals.columns.str.startswith("Summer")]
# Out:
#       SummerGame  SummerGold  SummerSilver  SummerBronze
# Code
# AFG           13           0             0             2
# ALG           12           5             2             8
# ARG           23          18            24            28
# ARM            5           1             2             9
# ANZ            2           3             4             5
# ...          ...         ...           ...           ...
# YUG           16          26            29            28
# IOP            1           0             1             2
# ZAM           12           0             1             1
# ZIM           12           3             4             1
# ZZX            3           8             5             4
#
# [146 rows x 4 columns]

# %% [markdown]
# ```8. แสดงข้อมูลเหรียญทองของโอลิมปิกฤดูร้อนและฤดูหนาวของประเทศไทย (THA) สิงคโปร์ (SIN) และมาเลเซีย (MAS) แสดงชื่อประเทศด้วย```

# %%
medals.loc[ ["THA", "SIN", "MAS"], ["Country", "SummerGold", "WinterGold"] ]
# Out:
#         Country  SummerGold  WinterGold
# Code
# THA    Thailand           7           0
# SIN   Singapore           0           0
# MAS    Malaysia           0           0

# %% [markdown]
# ```9. แสดงข้อมูลเหรียญเงินและเหรียญทองแดงของโอลิมปิคฤดูร้อนของประเทศฝรั่งเศส (FRA) และสเปน (ESP) แสดงชื่อประเทศด้วย```

# %%
medals.loc[ ["FRA", "ESP"], ["Country", "SummerSilver", "SummerGold"] ]
# Out:
#      Country  SummerSilver  SummerGold
# Code
# FRA   France           223         202
# ESP    Spain            59          37

# %% [markdown]
# ```10. แสดงประเทศที่เข้าร่วมโอลิมปิคฤดูร้อนมากกว่า 24 ครั้ง```

# %%
medals[medals.SummerGame > 24]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AUS       Australia          25         139           152           177
# AUT         Austria          26          18            33            35
# BEL         Belgium          25          37            52            53
# CAN          Canada          25          59            99           121
# DEN         Denmark          26          43            68            68
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# GRE          Greece          27          30            42            39
# HUN         Hungary          25         167           144           165
# ITA           Italy          26         198           166           185
# NED     Netherlands          25          77            85           104
# SWE          Sweden          26         143           164           176
# ...

# %% [markdown]
# ```11. แสดงประเทศที่เข้าร่วมโอลิมปิคฤดูร้อนมากกว่า 24 ครั้งแสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูร้อนมากกว่า 200 เหรียญ```

# %%
medals[(medals.SummerGame > 24) & (medals.SummerGold > 200)]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# FRA           22          31            31            47
# GBR           22          10             4            12
# USA           22          96           102            84

# %% [markdown]
# ```12. แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูร้อนมากกว่า 200 เหรียญ และเป็นเหรียญเงินมากกว่า 200 เหรียญ```

# %%
medals[(medals.SummerGold > 200) & (medals.SummerSilver > 200)]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# FRA           22          31            31            47
# GBR           22          10             4            12
# URS            9          78            57            59
# USA           22          96           102            84

# %% [markdown]
# ```13. แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูหนาวมากกว่าเหรียญเงินของโอลิมปิคฤดูหนาว```

# %%
medals[medals.WinterGold > medals.WinterSilver]
# Out:
#                      Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AUS                Australia          25         139           152
# BLR                  Belarus           5          12            24
# CAN                   Canada          25          59            99
# EST                  Estonia          11           9             9
# EUA   United Team of Germany           3          28            54
# GDR             East Germany           5         153           129
# GBR            Great Britain          27         236           272
# ITA                    Italy          26         198           166
# KOR              South Korea          16          81            82
# NOR                   Norway          24          56            49
# RUS                   Russia           5         132           121
# URS             Soviet Union           9         395           319
# EUN             Unified Team           1          45            38
# ...

# %% [markdown]
# ```14. แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูหนาวมากกว่าเหรียญเงินและเหรียญทองแดงของโอลิมปิคฤดูหนาวรวมกัน```

# %%
medals[medals.WinterGold > (medals.WinterSilver + medals.WinterBronze)]
# Out:
#          Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# EST      Estonia          11           9             9            15
# UZB   Uzbekistan           5           5             5            10
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# EST            9           4             2             1
# UZB            6           1             0             0

# %% [markdown]
# ```15. แสดงข้อมูลโอลิมปิกฤดูร้อนเท่านั้นของประเทศที่ชื่อขึ้นต้นด้วย 'A' ทั้งหมด```

# %%
medals.loc[medals.Country.str.startswith("A"), medals.columns.str.contains("Summer")]
# Out:
#       SummerGame  SummerGold  SummerSilver  SummerBronze
# Code
# AFG           13           0             0             2
# ALG           12           5             2             8
# ARG           23          18            24            28
# ARM            5           1             2             9
# ANZ            2           3             4             5
# AUS           25         139           152           177
# AUT           26          18            33            35
# AZE            5           6             5            15

# %% [markdown]
# ```16. ประเทศที่เข้าร่วมจำนวนโอลิมปิกฤดูร้อนมากที่สุดคือกี่ครั้ง```

# %%
medals.SummerGame.max()
# Out:
# 27

# %% [markdown]
# ```17. แสดงชื่อประเทศที่เข้าร่วมโอลิมปิกฤดูร้อนมากที่สุด (ระวัง!! อาจมีหลายประเทศ)```

# %%
medals[ medals.SummerGame == medals.SummerGame.max() ]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# GRE          Greece          27          30            42            39
# SUI     Switzerland          27          47            73            65
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# FRA           22          31            31            47
# GBR           22          10             4            12
# GRE           18           0             0             0
# SUI           22          50            40            48

# %% [markdown]
# ```18. จำนวนประเทศที่เข้าร่วมโอลิมปิกฤดูหนาวบ่อยที่สุดมีกี่ประเทศ```

# %%
medals[ medals.WinterGame == medals.WinterGame.max() ].shape[0]
# Out:
# 12

# %% [markdown]
# ```19. จำนวนเหรียญทั้งหมดที่แจกไปในโอลิมปิกฤดูหนาวรวมแล้วมีกี่เหรียญ```

# %%
print(medals.WinterGold.sum() + medals.WinterSilver.sum() + medals.WinterBronze.sum())
# Out:
# 2865

# %% [markdown]
# ```20. หาค่าเฉลี่ยของจำนวนเหรียญทองฤดูหนาวและฤดูร้อนต่อประเทศ```

# %%
medals["AvgWinterGold"] = medals["WinterGold"].div(medals["WinterGame"]).replace(np.nan, 0.0)
medals["AvgSummerGold"] = medals["SummerGold"].div(medals["SummerGame"]).replace(np.nan, 0.0)

medals.loc[:, ["AvgWinterGold", "AvgSummerGold"]]
# Out:
#       AvgWinterGold  AvgSummerGold
# Code
# AFG             0.0       0.000000
# ALG             0.0       0.416667
# ARG             0.0       0.782609
# ARM             0.0       0.200000
# ANZ             0.0       1.500000
# ...             ...            ...
# YUG             0.0       1.625000
# IOP             0.0       0.000000
# ZAM             0.0       0.000000
# ZIM             0.0       0.250000
# ZZX             0.0       2.666667
#
# [146 rows x 2 columns]

# %% [markdown]
# ```21. แสดงจำนวนเหรียญทั้งหมด(รวมฤดูร้อนและฤดูหนาว)ที่แต่ละประเทศได้```

# %%
print(medals.WinterGold.sum() + medals.WinterSilver.sum() + medals.WinterBronze.sum())
# Out:
# 2865

# %% [markdown]
# ```22. แสดงประเทศที่ได้เหรียญรวมทุกประเภทของโอลิมปิกฤดูหนาวมากกว่าเหรียญรวมโอลิมปิกฤดูร้อน ให้คอลัมน์ของตารางนี้แสดงชื่อประเทศ เหรียญรวมฤดูร้อน เหรียญรวมฤดูหนาว```

# %%
medals["SumSummer"] = medals["SummerGold"] + medals["SummerSilver"] + medals["SummerBronze"]
medals["SumWinter"] = medals["WinterGold"] + medals["WinterSilver"] + medals["WinterBronze"]
medals[medals.SumWinter > medals.SumSummer]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AUT         Austria          26          18            33            35
# LIE   Liechtenstein          16           0             0             0
# NOR          Norway          24          56            49            43
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  AvgWinterGold  \
# Code
# AUT           22          59            78            81       2.681818
# LIE           18           2             2             5       0.111111
# NOR           22         118           111           100       5.363636
#
#       AvgSummerGold  SumSummer  SumWinter
# Code
# AUT        0.692308         86        218
# LIE        0.000000          0          9
# NOR        2.333333        148        329

# %% [markdown]
# ```23. แสดงประเทศที่ไม่เคยได้เหรียญใดของโอลิมปิกฤดูร้อนแต่ได้เหรียญใดของฤดูหนาว หรือ ได้แต่เหรียญฤดูร้อนไม่เคยได้ฤดูหนาว```

# %%
medals[ ( ( medals.SumSummer == 0 ) & ( medals.SumWinter > 0 ) ) | ( ( medals.SumSummer > 0 ) & ( medals.SumWinter == 0 ) )].loc[:, ["SumSummer", "SumWinter"]].tail(20)
# Out:
#       SumSummer  SumWinter
# Code
# SYR           3          0
# TPE          21          0
# TJK           3          0
# TAN           2          0
# THA          24          0
# TOG           1          0
# TGA           1          0
# TRI          18          0
# TUN          10          0
# TUR          88          0
# UGA           7          0
# UAE           1          0
# URU          10          0
# VEN          12          0
# VIE           2          0
# ISV           1          0
# IOP           3          0
# ZAM           2          0
# ZIM           8          0
# ZZX          17          0

# %% [markdown]
# ```24. แสดงประเทศเรียงลำดับตามเหรียญทองฤดูร้อนจากน้อยไปมาก```

# %%
medals.sort_values(by="SummerGold")
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AFG     Afghanistan          13           0             0             2
# NAM         Namibia           6           0             4             0
# MNE      Montenegro           2           0             1             0
# MDA         Moldova           5           0             2             5
# MRI       Mauritius           8           0             0             1
# ...             ...         ...         ...           ...           ...
# CHN           China           9         201           146           126
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  AvgWinterGold  \
# Code
# ...

# %% [markdown]
# ```25. แสดงประเทศเรียงลำดับตามเหรียญทองฤดูร้อนจากมากไปน้อย ถ้าได้เหรียญทองฤดูร้อนเท่ากันให้เรียงตามจำนวนการเข้าแข่งฤดูร้อนจากน้อยไปมาก ```

# %%
medals.sort_values(by=["SummerGold", "SummerGame"], ascending=[True, False])
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# PHI     Philippines          20           0             2             7
# ISL         Iceland          19           0             2             2
# BER         Bermuda          17           0             0             1
# PUR     Puerto Rico          17           0             2             6
# GUY          Guyana          16           0             0             1
# ...             ...         ...         ...           ...           ...
# CHN           China           9         201           146           126
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  AvgWinterGold  \
# Code
# ...

# %% [markdown]
# ```26. ให้สร้างคอลัมน์ใหม่ในตาราง medals ให้ชื่อว่า score โดยคำนวณคะแนนรวมจากเหรียญที่แต่ละประเทศได้(ทั้งฤดูร้อนและหนาว) โดยให้เหรียญทองได้ 3 คะแนน เหรียญเงินได้ 2 คะแนน เหรียญทองแดงได้ 1 คะแนน แล้วแสดงข้อมูล 10 ประเทศแรกที่ได้คะแนนเยอะที่สุด```

# %%
medals["score"] = ((medals["SummerGold"] + medals["WinterGold"] * 3) +
                (medals["SummerSilver"] + medals["WinterSilver"] * 2) +
                (medals["SummerBronze"] + medals["WinterBronze"]))

medals.sort_values(by="score", ascending=True).head(10)
# Out:
#                    Country  SummerGame  SummerGold  SummerSilver  \
# Code
# GAB                  Gabon           9           0             1
# CIV            Ivory Coast          12           0             1
# AHO   Netherlands Antilles          13           0             1
# NIG                  Niger          11           0             0
# MRI              Mauritius           8           0             0
# PAR               Paraguay          11           0             1
# GRN                Grenada           8           1             0
# SEN                Senegal          13           0             1
# BDI                Burundi           5           1             0
# MKD              Macedonia           5           0             0
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze  \
# Code
# GAB              0           0           0             0             0
# CIV              0           0           0             0             0
# ...

# %% [markdown]
# ```27. การเปรียบเทียบคะแนนจากเหรียญทั้งหมดอาจจะไม่แฟร์ เพราะแต่ละประเทศเข้าร่วมการแข่งขันไม่เท่ากัน ดังนั้นให้สร้างคอลัมน์ใหม่ในตาราง medals ชื่อว่า perGame โดยคำนวณคะแนนต่อการเข้าร่วมแข่งขัน (คะแนนคำนวณเหมือนเดิม แต่หารด้วยจำนวนเกมส์ที่เข้าแข่งขัน แยกกันระหว่างฤดูร้อนกับฤดูหนาว ค่า perGame จะเป็นผลบวกของคะแนนของฤดูร้อนกับฤดูหนาว) แสดงข้อมูล 10 ประเทศที่ได้คะแนนน้อยที่สุด```

# %%
medals["perGame"] = medals["score"] / (medals["SummerGame"] + medals["WinterGame"])
medals.sort_values(by="perGame").head(10)
# Out:
#                    Country  SummerGame  SummerGold  SummerSilver  \
# Code
# BER                Bermuda          17           0             0
# CYP                 Cyprus           9           0             1
# ISV         Virgin Islands          11           0             1
# SEN                Senegal          13           0             1
# GUY                 Guyana          16           0             0
# AHO   Netherlands Antilles          13           0             1
# GUA              Guatemala          13           0             1
# IRQ                   Iraq          13           0             0
# PAR               Paraguay          11           0             1
# CIV            Ivory Coast          12           0             1
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze  \
# Code
# BER              1           7           0             0             0
# CYP              0          10           0             0             0
# ...
